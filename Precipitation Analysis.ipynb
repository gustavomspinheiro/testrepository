# %% [markdown]
# # Description
# Analyzes and visualizes precitipitation data

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Country or Area  Year    Value Value Footnotes                  Unit  \
# 0         Albania  2015  32711.0             NaN  million cubic metres
# 1         Albania  2014  37172.0             NaN  million cubic metres
# 2         Albania  2013  30615.0             NaN  million cubic metres
# 3         Albania  2012  28058.0             NaN  million cubic metres
# 4         Albania  2011  30569.0             NaN  million cubic metres
#
#   Value Footnotes.1
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_data_1.drop(['Value Footnotes', 'Unit', 'Value Footnotes.1'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/wsuser/ipykernel_154/974029241.py in <module>
# ----> 1 df_data_1.drop(['Value Footnotes', 'Unit', 'Value Footnotes.1'], inplace=True, axis=1)
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/envs/Python-3.9/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df_data_1 = pd.pivot_table(df_data_1, values='Value', index=['Country or Area'], columns=['Year'])
df_data_1.head()
# Out:
# Year                         1990        1991        1992   1993        1994  \
# Country or Area
# Albania              28385.000000         NaN         NaN    NaN         NaN
# Algeria              76160.000000         NaN         NaN    NaN         NaN
# Andorra                471.779297         NaN         NaN    NaN         NaN
# Anguilla                93.099998         NaN         NaN    NaN         NaN
# Antigua and Barbuda    300.299988  264.399994  475.799988  322.5  283.799988
#
# Year                         1995          1996          1997          1998  \
# Country or Area
# Albania              40311.000000           NaN           NaN           NaN
# Algeria              90270.000000  53380.000000  74460.000000  66470.000000
# Andorra                424.851898    625.167847    444.750214    361.244934
# Anguilla               100.730003           NaN           NaN           NaN
# Antigua and Barbuda    374.500000    323.299988    279.200012    384.500000
#
# ...

# %%
df_data_1.drop(['1991', '1992', '1993', '1994'], inplace=True, axis=1)
df_data_1.head()
# Out:
# Year                         1990          1995          1996          1997  \
# Country or Area
# Albania              28385.000000  40311.000000           NaN           NaN
# Algeria              76160.000000  90270.000000  53380.000000  74460.000000
# Andorra                471.779297    424.851898    625.167847    444.750214
# Anguilla                93.099998    100.730003           NaN           NaN
# Antigua and Barbuda    300.299988    374.500000    323.299988    279.200012
#
# Year                         1998          1999          2000          2001  \
# Country or Area
# Albania                       NaN  38284.000000  30683.000000  30491.000000
# Algeria              66470.000000  50150.000000  64430.000000  80000.000000
# Andorra                361.244934    480.914368    489.565796    427.232391
# Anguilla                      NaN           NaN     68.190002     70.730003
# Antigua and Barbuda    384.500000    426.799988    249.600006    238.000000
#
# ...

# %%
df_data_1 = df_data_1.fillna(0)
df_data_1.head()
# Out:
# Year                         1990          1995          1996          1997  \
# Country or Area
# Albania              28385.000000  40311.000000      0.000000      0.000000
# Algeria              76160.000000  90270.000000  53380.000000  74460.000000
# Andorra                471.779297    424.851898    625.167847    444.750214
# Anguilla                93.099998    100.730003      0.000000      0.000000
# Antigua and Barbuda    300.299988    374.500000    323.299988    279.200012
#
# Year                         1998          1999          2000          2001  \
# Country or Area
# Albania                  0.000000  38284.000000  30683.000000  30491.000000
# Algeria              66470.000000  50150.000000  64430.000000  80000.000000
# Andorra                361.244934    480.914368    489.565796    427.232391
# Anguilla                 0.000000      0.000000     68.190002     70.730003
# Antigua and Barbuda    384.500000    426.799988    249.600006    238.000000
#
# ...
